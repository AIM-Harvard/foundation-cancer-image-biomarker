# %% [markdown]
# ## Reproduce Analysis for Task 1 corresponding to Figure 2 in the paper.
#
# This notebook contains code and analysis for reproducing results for Figure 2

# %%
import pandas as pd
from pathlib import Path
from functools import partial
from tqdm import tqdm
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import plotly.io as pio
import numpy as np

from utils import get_model_stats, get_model_comparison_stats

pio.templates["custom"] = go.layout.Template(
    layout=go.Layout(
        colorway=px.colors.qualitative.D3,
    )
)

# %% [markdown]
# ### Load CSV files for each of the implementation approach predictions
#
# We load saved prediction files for each of the implementation approaches. The CSV contains the predicted probabilities for each of the 8 anatomical sites and the true label from the dataset. It also contains information about several other parameters such as lesion type, etc.

# %%
path = Path("../outputs/predictions/task1")

# %%
implementation_dict = {
    "Foundation (Features)": [csv_path for csv_path in path.glob("foundation_features*.csv")],
    "Foundation (Finetuned)": [csv_path for csv_path in path.glob("foundation_finetuned*.csv")],
    "Supervised": [csv_path for csv_path in path.glob("supervised*.csv")],
    "Med3D (Features)": [csv_path for csv_path in path.glob("med3d_features*.csv")],
    "Med3D (Finetuned)": [csv_path for csv_path in path.glob("med3d_finetuned*.csv")],
    "Models Genesis (Features)": [csv_path for csv_path in path.glob("modelsgen_features*.csv")],
    "Models Genesis (Finetuned)": [csv_path for csv_path in path.glob("modelsgen_finetuned*.csv")],
}

implementation_rank = {key: i for i, key in enumerate(implementation_dict.keys())}

# %% [markdown]
# ### Analysis for computing metrics for each of the implementation approaches
#
# Here we compute the metrics for each of the implementation approaches along with the 95% confidence intervals. Each implementation approach is also compared to all other implementation
# approaches with a difference confidence interval and p-value. We bootstrap to compute the confidence intervals and run a permutation test for the p-values.

# %%
pbar = tqdm(total=len(implementation_dict) * len(implementation_dict["Supervised"]))
results = []

# We use 1000 resamples in the study, but for the sake of time we use reproduce results with 10 here
N_RESAMPLES = 10

for implementation_name, implementation_list in implementation_dict.items():
    for model_prediction_csv in implementation_list:
        data_percentage = (
            float(model_prediction_csv.stem.split("_")[-2]) / 100 if len(model_prediction_csv.stem.split("_")) > 2 else 1.0
        )
        df = pd.read_csv(model_prediction_csv)

        for i in range(8):
            if f"conf_scores_class_{i}" not in df.columns:
                df[f"conf_scores_class_{i}"] = 0

        pred_set = (df["Coarse_lesion_type"].values, df.filter(like="conf_scores").values)
        map_values = get_model_stats(
            *pred_set,
            fn="mean_average_precision",
            nsamples=N_RESAMPLES,
        )

        ba_values = get_model_stats(
            *pred_set,
            fn="balanced_accuracy",
            nsamples=N_RESAMPLES,
        )

        row = {
            "Implementation": implementation_name,
            "Data Percentage": data_percentage,
            "mAP": np.mean(map_values),
            "mAP_values": map_values,
            "mAP_low_CI": np.percentile(map_values, 2.5),
            "mAP_high_CI": np.percentile(map_values, 97.5),
            "BA": np.mean(ba_values),
            "BA_low_CI": np.percentile(ba_values, 2.5),
            "BA_high_CI": np.percentile(ba_values, 97.5),
            "BA_values": ba_values,
        }

        # Compute statistics for comparison between this implementation and all other ones (difference CI and p-value)
        compare_impementations = {k: v for k, v in implementation_dict.items() if k != implementation_name}
        for _implementation_name, _implementations_list in compare_impementations.items():
            for _model_prediction_csv in _implementations_list:
                _data_percentage = (
                    float(_model_prediction_csv.stem.split("_")[-2]) / 100
                    if len(_model_prediction_csv.stem.split("_")) > 2
                    else 1.0
                )
                if data_percentage == _data_percentage:
                    _df = pd.read_csv(_model_prediction_csv)
                    # Check if 8 columns with conf_scores_class_{idx} exist, if not add a column with zeros for missing
                    for i in range(8):
                        if f"conf_scores_class_{i}" not in _df.columns:
                            _df[f"conf_scores_class_{i}"] = 0

                    _pred = _df.filter(like="conf_scores").values
                    _pred_set = (*pred_set, _pred)

                    perm_test = get_model_comparison_stats(
                        *_pred_set,
                        fn="balanced_accuracy",
                        nsamples=N_RESAMPLES,
                    )

                    row[f"BA_diff_CI_low_{_implementation_name}"] = perm_test[0][0]
                    row[f"BA_diff_CI_high_{_implementation_name}"] = perm_test[0][1]
                    row[f"BA_pval_{_implementation_name}"] = perm_test[1]

                    perm_test = get_model_comparison_stats(
                        *_pred_set,
                        fn="mean_average_precision",
                        nsamples=N_RESAMPLES,
                    )

                    row[f"mAP_diff_CI_low_{_implementation_name}"] = perm_test[0][0]
                    row[f"mAP_diff_CI_high_{_implementation_name}"] = perm_test[0][1]
                    row[f"mAP_pval_{_implementation_name}"] = perm_test[1]

        results.append(row)
        pbar.update(1)
# Out:
# 0it [00:00, ?it/s]

# %%
# results_df = pd.DataFrame(results)

results_df = pd.read_pickle("task1.pkl")
# results_df = pd.read_csv("result_csvs/task1_fixed.csv")
results_df["Implementation_Rank"] = results_df["Implementation"].map(implementation_rank)
results_df.sort_values(by=["Data Percentage", "Implementation_Rank"], inplace=True, ascending=True)
results_df.drop("Implementation_Rank", axis=1, inplace=True)

# %%
results_df[results_df["Data Percentage"] == 1]
# Out:
#                 Implementation  Data Percentage       mAP  \
# 3        Foundation (Features)              1.0  0.847815
# 4       Foundation (Finetuned)              1.0  0.855878
# 9                   Supervised              1.0  0.821244
# 12            Med3D (Features)              1.0  0.659406
# 17           Med3D (Finetuned)              1.0  0.813114
# 23   Models Genesis (Features)              1.0  0.791329
# 26  Models Genesis (Finetuned)              1.0  0.819371
#
#                                            mAP_values  mAP_low_CI  \
# 3   [0.8432566196960686, 0.8619535147862756, 0.848...    0.816616
# 4   [0.8513567507818766, 0.8454574271013343, 0.855...    0.826309
# 9   [0.8298386861958249, 0.8194270500611527, 0.820...    0.788203
# 12  [0.6646172568418498, 0.6424729169054022, 0.633...    0.625010
# 17  [0.8075177935852775, 0.8391844055603279, 0.792...    0.779779
# 23  [0.7842390625693547, 0.7718743295516455, 0.787...    0.760146
# 26  [0.8309974656706345, 0.8160368114561494, 0.819...    0.786681
#
#     mAP_high_CI        BA  BA_low_CI  BA_high_CI  \
# 3      0.878474  0.779430   0.746945    0.809909
# 4      0.882107  0.804614   0.775275    0.834946
# 9      0.853220  0.720204   0.689028    0.751029
# 12     0.692738  0.614128   0.581554    0.646572
# 17     0.846698  0.783501   0.749730    0.816687
# 23     0.821855  0.698173   0.666347    0.729977
# 26     0.850924  0.768038   0.734784    0.800054
#
#                                             BA_values  ...  \
# 3   [0.7945897019722147, 0.7890314542662229, 0.769...  ...
# 4   [0.8368961112148825, 0.7995212924206898, 0.790...  ...
# 9   [0.7155627357973212, 0.7505271681199173, 0.745...  ...
# 12  [0.6417301485834737, 0.620391726417544, 0.6314...  ...
# 17  [0.8023502379761918, 0.7716968512557327, 0.794...  ...
# 23  [0.6763925218525426, 0.7079235605071561, 0.703...  ...
# 26  [0.7554206850752618, 0.7641704225114363, 0.785...  ...
#
#     BA_pval_Models Genesis (Finetuned)  \
# 3                                0.252
# 4                                0.021
# 9                                0.994
# 12                               1.000
# 17                               0.165
# 23                               1.000
# 26                                 NaN
#
#     mAP_diff_CI_low_Models Genesis (Finetuned)  \
# 3                                    -0.002126
# 4                                     0.011554
# 9                                    -0.030026
# 12                                   -0.197424
# 17                                   -0.033516
# 23                                   -0.061754
# 26                                         NaN
#
#     mAP_diff_CI_high_Models Genesis (Finetuned)  \
# 3                                      0.056877
# 4                                      0.065391
# 9                                      0.037112
# 12                                    -0.120428
# 17                                     0.023737
# 23                                     0.006030
# 26                                          NaN
#
#     mAP_pval_Models Genesis (Finetuned)  BA_diff_CI_low_Foundation (Features)  \
# 3                                 0.034                                   NaN
# 4                                 0.006                             -0.006785
# 9                                 0.449                             -0.093282
# 12                                1.000                             -0.204459
# 17                                0.625                             -0.032690
# 23                                0.920                             -0.119392
# 26                                  NaN                             -0.044366
#
#     BA_diff_CI_high_Foundation (Features)  BA_pval_Foundation (Features)  \
# 3                                     NaN                            NaN
# 4                                0.058291                          0.070
# 9                               -0.025713                          1.000
# 12                              -0.126445                          1.000
# 17                               0.036007                          0.440
# 23                              -0.041760                          1.000
# 26                               0.021408                          0.754
#
#     mAP_diff_CI_low_Foundation (Features)  \
# 3                                     NaN
# 4                               -0.016243
# 9                               -0.051811
# 12                              -0.224831
# 17                              -0.059902
# 23                              -0.084257
# 26                              -0.061244
#
#     mAP_diff_CI_high_Foundation (Features)  mAP_pval_Foundation (Features)
# 3                                      NaN                             NaN
# 4                                 0.036086                           0.244
# 9                                 0.001941                           0.949
# 12                               -0.153194                           1.000
# 17                               -0.006134                           0.992
# 23                               -0.024382                           0.999
# 26                                0.000282                           0.962
#
# [7 rows x 52 columns]

# %%
df = pd.read_csv("/home/suraj/Repositories/foundation-cancer-image-biomarker/preds.csv")

# %%
pred_set = (df["Coarse_lesion_type"].values, df.filter(like="pred").values)

map_values = get_model_stats(
    *pred_set,
    fn="mean_average_precision",
    nsamples=N_RESAMPLES,
)

ba_values = get_model_stats(
    *pred_set,
    fn="balanced_accuracy",
    nsamples=N_RESAMPLES,
)

print(np.mean(map_values), np.mean(ba_values))
# Out:
# 0.821850765753539 0.8034750643549391

# %% [markdown]
# ### Generate the figures
# The figures are reproduced using plotly

# %%
gray_palette = sns.color_palette("gray", 6).as_hex()

# %%
results_df_ = results_df[results_df["Data Percentage"] == 1]
for metric in ["mAP", "BA"]:
    results_df_[f"e_plus_{metric}"] = results_df_[f"{metric}_high_CI"] - results_df_[metric]
    results_df_[f"e_minus_{metric}"] = results_df_[metric] - results_df_[f"{metric}_low_CI"]
    metric_values = results_df_[f"{metric}_values"].values

    colors = ["#3182BD", "#00A3D5", gray_palette[0], *gray_palette[2:]]

    fig = px.bar(
        results_df_,
        x="Implementation",
        y=metric,
        error_y=f"e_plus_{metric}",
        error_y_minus=f"e_minus_{metric}",
        color="Implementation",
        template="simple_white",
        labels={"Model": "", metric: metric, "Implementation": "Implementation approaches"},
        color_discrete_sequence=colors,  # Use the blues color palette
        range_y=[0.4, 1],
    )

    random_val = np.random.rand(len(metric_values[0]))
    for sample_idx in range(len(metric_values[0])):
        fig.add_trace(
            go.Box(
                x=results_df_["Implementation"],
                y=[metric_values[i][sample_idx] for i in range(len(metric_values))],
                marker=dict(color="black", symbol="circle", size=1, line=dict(width=0)),
                fillcolor="rgba(255, 255, 255,0)",
                line=dict(
                    width=0,
                ),
                boxpoints="all",  # display the original data points
                opacity=0.2,
                pointpos=-1.6 + (random_val[sample_idx] * 3.2),
                showlegend=False,
            )
        )

    title = "Full training set"
    fig.update_layout(
        title=title,
        width=600,
        height=500,
        autosize=False,
        legend=dict(
            orientation="v",
        ),
        template="simple_white",
        bargap=0,
        title_x=0.5,
        xaxis=dict(showticklabels=False),
        yaxis=dict(showgrid=True),
        xaxis_title=None,
        showlegend=True,
    ),
    for trace in fig.data:
        if isinstance(trace, go.Bar):
            trace.error_y.thickness = 1

    fig.show()
    fig.write_image(f"figures_vector_pdf/task1_{metric}_dot.pdf")
    fig.data = []
# Out:
# /tmp/ipykernel_2861128/3933930864.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2861128/3933930864.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="9ecee7ce-82b9-448d-8218-8e33a37c3c5f" class="plotly-graph-div" style="height:500px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ecee7ce-82b9-448d-8218-8e33a37c3c5f")) {                    Plotly.newPlot(                        "9ecee7ce-82b9-448d-8218-8e33a37c3c5f",                        [{"alignmentgroup":"True","error_y":{"array":[0.030658347506671402],"arrayminus":[0.031199261863763206],"thickness":1},"hovertemplate":"Implementation approaches=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Features)","marker":{"color":"#3182BD","pattern":{"shape":""}},"name":"Foundation (Features)","offsetgroup":"Foundation (Features)","orientation":"v","showlegend":true,"textposition":"auto","x":["Foundation (Features)"],"xaxis":"x","y":[0.8478154825210746],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.026228165910077816],"arrayminus":[0.02956970942168624],"thickness":1},"hovertemplate":"Implementation approaches=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Finetuned)","marker":{"color":"#00A3D5","pattern":{"shape":""}},"name":"Foundation (Finetuned)","offsetgroup":"Foundation (Finetuned)","orientation":"v","showlegend":true,"textposition":"auto","x":["Foundation (Finetuned)"],"xaxis":"x","y":[0.8558783589463935],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.03197638187294016],"arrayminus":[0.03304125174000838],"thickness":1},"hovertemplate":"Implementation approaches=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supervised","marker":{"color":"#242424","pattern":{"shape":""}},"name":"Supervised","offsetgroup":"Supervised","orientation":"v","showlegend":true,"textposition":"auto","x":["Supervised"],"xaxis":"x","y":[0.8212441061133203],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.033332176242595435],"arrayminus":[0.0343950389326384],"thickness":1},"hovertemplate":"Implementation approaches=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Features)","marker":{"color":"#6d6d6d","pattern":{"shape":""}},"name":"Med3D (Features)","offsetgroup":"Med3D (Features)","orientation":"v","showlegend":true,"textposition":"auto","x":["Med3D (Features)"],"xaxis":"x","y":[0.6594055127148595],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.03358439201509855],"arrayminus":[0.03333474294219618],"thickness":1},"hovertemplate":"Implementation approaches=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Finetuned)","marker":{"color":"#929292","pattern":{"shape":""}},"name":"Med3D (Finetuned)","offsetgroup":"Med3D (Finetuned)","orientation":"v","showlegend":true,"textposition":"auto","x":["Med3D (Finetuned)"],"xaxis":"x","y":[0.813113898654241],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.030525980060838287],"arrayminus":[0.031183282857671468],"thickness":1},"hovertemplate":"Implementation approaches=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Models Genesis (Features)","marker":{"color":"#b6b6b6","pattern":{"shape":""}},"name":"Models Genesis (Features)","offsetgroup":"Models Genesis (Features)","orientation":"v","showlegend":true,"textposition":"auto","x":["Models Genesis (Features)"],"xaxis":"x","y":[0.7913289470231522],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.03155256678972196],"arrayminus":[0.03269050953893249],"thickness":1},"hovertemplate":"Implementation approaches=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Models Genesis (Finetuned)","marker":{"color":"#dbdbdb","pat ...
# /tmp/ipykernel_2861128/3933930864.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_2861128/3933930864.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="6e22da4a-7a66-4eee-b131-1b7453480142" class="plotly-graph-div" style="height:500px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e22da4a-7a66-4eee-b131-1b7453480142")) {                    Plotly.newPlot(                        "6e22da4a-7a66-4eee-b131-1b7453480142",                        [{"alignmentgroup":"True","error_y":{"array":[0.030478643822621665],"arrayminus":[0.03248578995922147],"thickness":1},"hovertemplate":"Implementation approaches=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Features)","marker":{"color":"#3182BD","pattern":{"shape":""}},"name":"Foundation (Features)","offsetgroup":"Foundation (Features)","orientation":"v","showlegend":true,"textposition":"auto","x":["Foundation (Features)"],"xaxis":"x","y":[0.7794304477600082],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.030332071358010637],"arrayminus":[0.02933917437598821],"thickness":1},"hovertemplate":"Implementation approaches=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Finetuned)","marker":{"color":"#00A3D5","pattern":{"shape":""}},"name":"Foundation (Finetuned)","offsetgroup":"Foundation (Finetuned)","orientation":"v","showlegend":true,"textposition":"auto","x":["Foundation (Finetuned)"],"xaxis":"x","y":[0.8046137242698607],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.030824374484409778],"arrayminus":[0.03117600071762039],"thickness":1},"hovertemplate":"Implementation approaches=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supervised","marker":{"color":"#242424","pattern":{"shape":""}},"name":"Supervised","offsetgroup":"Supervised","orientation":"v","showlegend":true,"textposition":"auto","x":["Supervised"],"xaxis":"x","y":[0.7202044163473635],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.03244320596233885],"arrayminus":[0.0325744839686779],"thickness":1},"hovertemplate":"Implementation approaches=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Features)","marker":{"color":"#6d6d6d","pattern":{"shape":""}},"name":"Med3D (Features)","offsetgroup":"Med3D (Features)","orientation":"v","showlegend":true,"textposition":"auto","x":["Med3D (Features)"],"xaxis":"x","y":[0.6141283584907314],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.03318600172043795],"arrayminus":[0.0337702043543846],"thickness":1},"hovertemplate":"Implementation approaches=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Finetuned)","marker":{"color":"#929292","pattern":{"shape":""}},"name":"Med3D (Finetuned)","offsetgroup":"Med3D (Finetuned)","orientation":"v","showlegend":true,"textposition":"auto","x":["Med3D (Finetuned)"],"xaxis":"x","y":[0.7835005557323591],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.03180477315417651],"arrayminus":[0.03182540251038457],"thickness":1},"hovertemplate":"Implementation approaches=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Models Genesis (Features)","marker":{"color":"#b6b6b6","pattern":{"shape":""}},"name":"Models Genesis (Features)","offsetgroup":"Models Genesis (Features)","orientation":"v","showlegend":true,"textposition":"auto","x":["Models Genesis (Features)"],"xaxis":"x","y":[0.6981727248739846],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.03201621353719264],"arrayminus":[0.03325354721026985],"thickness":1},"hovertemplate":"Implementation approaches=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Models Genesis (Finetuned)","marker":{"color":"#dbdbdb","pattern":{"sh ...

# %%
for metric in ["mAP", "BA"]:
    results_df[f"e_plus_{metric}"] = results_df[f"{metric}_high_CI"] - results_df[metric]
    results_df[f"e_minus_{metric}"] = results_df[metric] - results_df[f"{metric}_low_CI"]

    fig = px.line(
        results_df,
        x="Data Percentage",
        y=metric,
        # error_y=f"e_plus_{metric}",
        # error_y_minus=f"e_minus_{metric}",
        color="Implementation",
        markers=True,
        template="simple_white",
        labels={"Data Percentage": "Percentage", metric: metric},
        color_discrete_sequence=colors,  # Use the blues color palette
        range_y=[0.4, 1],
    )

    fig.update_traces(marker=dict(size=10))
    # fig.update_traces(marker=dict(symbol="star"))

    title = "Percentages of training data"
    fig.update_traces(
        error_y=dict(
            thickness=1,
        ),
    )
    fig.update_layout(
        title=title,
        width=600,
        height=600,
        autosize=True,
        showlegend=False,
        legend=dict(yanchor="bottom", y=-0.4, orientation="h", xanchor="right", x=1),
        template="simple_white",
        title_x=0.5,
        yaxis=dict(showgrid=True),
        xaxis=dict(
            tickmode="array",  # change 1
            tickvals=[0.1, 0.2, 0.5, 1],  # change 2
            ticktext=["10%", "20%", "50%", "100%"],  # change 3
            autorange="reversed",
        ),
    )

    fig.show()
    fig.write_image(f"figures_vector_pdf/task1_{metric}_percentages.pdf")
    fig.data = []
# Out:
# <div>                            <div id="be2a9ac4-14e9-4ae9-a74e-535499e13ec7" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be2a9ac4-14e9-4ae9-a74e-535499e13ec7")) {                    Plotly.newPlot(                        "be2a9ac4-14e9-4ae9-a74e-535499e13ec7",                        [{"hovertemplate":"Implementation=Foundation (Features)\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Features)","line":{"color":"#3182BD","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Foundation (Features)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.7425803060793097,0.781202262880646,0.8198943157991733,0.8478154825210746],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Foundation (Finetuned)\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Finetuned)","line":{"color":"#00A3D5","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Foundation (Finetuned)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.6169679519959644,0.7261938428308471,0.8131072852854623,0.8558783589463935],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Supervised\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supervised","line":{"color":"#242424","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Supervised","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.5954412626958945,0.607316561687818,0.6867215004264681,0.8212441061133203],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Med3D (Features)\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Features)","line":{"color":"#6d6d6d","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Med3D (Features)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.548543907533648,0.5974088684555998,0.6304073536047747,0.6594055127148595],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Med3D (Finetuned)\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Finetuned)","line":{"color":"#929292","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Med3D (Finetuned)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.5581206158008563,0.6248035734050511,0.7776464109095153,0.813113898654241],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Models Genesis (Features)\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Models Genesis (Features)","line":{"color":"#b6b6b6","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Models Genesis (Features)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.6259947082804206,0.6740668545810865,0.7636312700482362,0.7913289470231522],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Models Genesis (Finetuned)\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Models Genesis (Finetuned)","line":{"color":"#dbdbdb","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Models Genesis (Finetuned)","orientation": ...
# <div>                            <div id="a07e75da-ed1d-46cc-b1c2-14bbfa72a059" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a07e75da-ed1d-46cc-b1c2-14bbfa72a059")) {                    Plotly.newPlot(                        "a07e75da-ed1d-46cc-b1c2-14bbfa72a059",                        [{"hovertemplate":"Implementation=Foundation (Features)\u003cbr\u003ePercentage=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Features)","line":{"color":"#3182BD","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Foundation (Features)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.7064236518437297,0.7098565377847356,0.7451907011565372,0.7794304477600082],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Foundation (Finetuned)\u003cbr\u003ePercentage=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Finetuned)","line":{"color":"#00A3D5","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Foundation (Finetuned)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.5812886129460058,0.6460807701289953,0.7721446927859057,0.8046137242698607],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Supervised\u003cbr\u003ePercentage=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supervised","line":{"color":"#242424","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Supervised","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.5193260748506675,0.5162049194848395,0.592082486554341,0.7202044163473635],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Med3D (Features)\u003cbr\u003ePercentage=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Features)","line":{"color":"#6d6d6d","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Med3D (Features)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.5633114170437368,0.5620346483805282,0.5636569497901787,0.6141283584907314],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Med3D (Finetuned)\u003cbr\u003ePercentage=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Finetuned)","line":{"color":"#929292","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Med3D (Finetuned)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.4857296279914415,0.5894822569382533,0.6890385926979424,0.7835005557323591],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Models Genesis (Features)\u003cbr\u003ePercentage=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Models Genesis (Features)","line":{"color":"#b6b6b6","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Models Genesis (Features)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.5559828423995146,0.6232742479296405,0.6859254148233533,0.6981727248739846],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Models Genesis (Finetuned)\u003cbr\u003ePercentage=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Models Genesis (Finetuned)","line":{"color":"#dbdbdb","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Models Genesis (Finetuned)","orientation":"v", ...
