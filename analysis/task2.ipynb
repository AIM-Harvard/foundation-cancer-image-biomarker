# %% [markdown]
# ## Reproduce Analysis for Task 2 corresponding to Figure 3 in the paper.
#
# This notebook contains code and analysis for reproducing results for Figure 3

# %%
from scipy.stats import bootstrap, permutation_test
import pandas as pd
from pathlib import Path
from functools import partial
from tqdm import tqdm
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import seaborn as sns


pio.templates["custom"] = go.layout.Template(
    layout=go.Layout(
        colorway=px.colors.qualitative.D3,
    )
)

from utils import get_model_stats, get_model_comparison_stats

# %% [markdown]
# ### Load CSV files for each of the implementation approach predictions
#
# We load saved prediction files for each of the implementation approaches. The CSV contains the predicted probabilities for malignancy and the true label from the dataset.

# %%
path = Path("../outputs/predictions/task2")

# %%
implementation_dict = {
    "Foundation (Features)": [csv_path for csv_path in path.glob("foundation_features*.csv")],
    "Foundation (Finetuned)": [csv_path for csv_path in path.glob("foundation_finetuned*.csv")],
    "Supervised": [csv_path for csv_path in path.glob("supervised_random*.csv")],
    "Supervised (Finetuned)": [csv_path for csv_path in path.glob("supervised_finetuned*.csv")],
    "Med3D (Features)": [csv_path for csv_path in path.glob("med3d_features*.csv")],
    "Med3D (Finetuned)": [csv_path for csv_path in path.glob("med3d_finetuned*.csv")],
    "Models Genesis (Features)": [csv_path for csv_path in path.glob("modelsgen_features*.csv")],
    "Models Genesis (Finetuned)": [csv_path for csv_path in path.glob("modelsgen_finetuned*.csv")],
}

implementation_rank = {key: i for i, key in enumerate(implementation_dict.keys())}

# %% [markdown]
# ### Analysis for computing metrics for each of the implementation approaches
#
# Here we compute the metrics for each of the implementation approaches along with the 95% confidence intervals. Each implementation approach is also compared to all other implementation
# approaches with a difference confidence interval and p-value. We bootstrap to compute the confidence intervals and run a permutation test for the p-values.

# %%
pbar = tqdm(total=len(implementation_dict) * len(implementation_dict["Supervised"]))
results = []

# We use 1000 resamples in the study, but for the sake of time we use reproduce results with 10 here
N_RESAMPLES = 1000

for implementation_name, implementation_list in implementation_dict.items():
    for model_prediction_csv in implementation_list:
        data_percentage = (
            float(model_prediction_csv.stem.split("_")[-2]) / 100 if len(model_prediction_csv.stem.split("_")) > 2 else 1.0
        )
        df = pd.read_csv(model_prediction_csv)
        pred_set = (
            df["malignancy"].values,
            df["conf_scores_class_1"].values if "conf_scores_class_1" in df.columns else df["conf_scores_class"].values,
        )

        map_values = get_model_stats(
            *pred_set,
            fn="average_precision_score",
            nsamples=N_RESAMPLES,
        )

        auc_values = get_model_stats(
            *pred_set,
            fn="roc_auc_score",
            nsamples=N_RESAMPLES,
        )
        row = {
            "Implementation": implementation_name,
            "Data Percentage": data_percentage,
            "mAP": np.mean(map_values),
            "mAP_values": map_values,
            "mAP_low_CI": np.percentile(map_values, 2.5),
            "mAP_high_CI": np.percentile(map_values, 97.5),
            "AUC": np.mean(auc_values),
            "AUC_low_CI": np.percentile(auc_values, 2.5),
            "AUC_high_CI": np.percentile(auc_values, 97.5),
            "AUC_values": auc_values,
        }

        # Compute statistics for comparison between this implementation and all other ones (difference CI and p-value)
        compare_impementations = {k: v for k, v in implementation_dict.items() if k != implementation_name}
        for _implementation_name, _implementations_list in compare_impementations.items():
            for _model_prediction_csv in _implementations_list:
                _data_percentage = (
                    float(_model_prediction_csv.stem.split("_")[-2]) / 100
                    if len(_model_prediction_csv.stem.split("_")) > 2
                    else 1.0
                )
                if data_percentage == _data_percentage:
                    _df = pd.read_csv(_model_prediction_csv)
                    _pred = (
                        _df["conf_scores_class_1"].values
                        if "conf_scores_class_1" in _df.columns
                        else _df["conf_scores_class"].values
                    )
                    _pred_set = (*pred_set, _pred)

                    perm_test = get_model_comparison_stats(
                        *_pred_set,
                        fn="roc_auc_score",
                        nsamples=N_RESAMPLES,
                    )

                    row[f"AUC_diff_CI_low_{_implementation_name}"] = perm_test[0][0]
                    row[f"AUC_diff_CI_high_{_implementation_name}"] = perm_test[0][1]
                    row[f"AUC_pval_{_implementation_name}"] = perm_test[1]

                    perm_test = get_model_comparison_stats(
                        *_pred_set,
                        fn="average_precision_score",
                        nsamples=N_RESAMPLES,
                    )

                    row[f"mAP_diff_CI_low_{_implementation_name}"] = perm_test[0][0]
                    row[f"mAP_diff_CI_high_{_implementation_name}"] = perm_test[0][1]
                    row[f"mAP_pval_{_implementation_name}"] = perm_test[1]

        results.append(row)
        pbar.update(1)
# Out:
#   3%|▎         | 1/32 [00:41<21:20, 41.31s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/task2.ipynb Cell 7 line 6
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/task2.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=52'>53</a> _pred = (
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/task2.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=53'>54</a>     _df["conf_scores_class_1"].values
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/task2.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=54'>55</a>     if "conf_scores_class_1" in _df.columns
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/task2.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=55'>56</a>     else _df["conf_scores_class"].values
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/task2.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=56'>57</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/task2.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=57'>58</a> _pred_set = (*pred_set, _pred)
# ---> <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/task2.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=59'>60</a> perm_test = get_model_comparison_stats(
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/task2.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=60'>61</a>     *_pred_set,
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/task2.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=61'>62</a>     fn="roc_auc_score",
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/task2.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=62'>63</a>     nsamples=N_RESAMPLES,
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/task2.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=63'>64</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/task2.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=65'>66</a> row[f"AUC_diff_CI_low_{_implementation_name}"] = perm_test[0][0]
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/task2.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=66'>67</a> row[f"AUC_diff_CI_high_{_implementation_name}"] = perm_test[0][1]
#
# File ~/Repositories/foundation-cancer-image-biomarker/analysis/utils.py:39, in get_model_comparison_stats(y_true, pred_proba_1, pred_proba_2, nsamples, fn)
#      37 p2 = np.where(mask, pred_proba_2, pred_proba_1)
#      38 metric1 = eval(fn)(y_true, p1)
# ---> 39 metric2 = eval(fn)(y_true, p2)
#      40 auc_differences.append(metric1 - metric2)
#      42 idx = np.random.randint(y_true.shape[0], size=y_true.shape[0])
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:626, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     624     labels = np.unique(y_true)
#     625     y_true = label_binarize(y_true, classes=labels)[:, 0]
# --> 626     return _average_binary_score(
#     627         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     628         y_true,
#     629         y_score,
#     630         average,
#     631         sample_weight=sample_weight,
#     632     )
#     633 else:  # multilabel-indicator
#     634     return _average_binary_score(
#     635         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     636         y_true,
#    (...)
#     639         sample_weight=sample_weight,
#     640     )
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/metrics/_base.py:75, in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      72     raise ValueError("{0} format is not supported".format(y_type))
#      74 if y_type == "binary":
# ---> 75     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      77 check_consistent_length(y_true, y_score, sample_weight)
#      78 y_true = check_array(y_true)
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:386, in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     380 if len(np.unique(y_true)) != 2:
#     381     raise ValueError(
#     382         "Only one class present in y_true. ROC AUC score "
#     383         "is not defined in that case."
#     384     )
# --> 386 fpr, tpr, _ = roc_curve(y_true, y_score, sample_weight=sample_weight)
#     387 if max_fpr is None or max_fpr == 1:
#     388     return auc(fpr, tpr)
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:184, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     182 global_skip_validation = get_config()["skip_parameter_validation"]
#     183 if global_skip_validation:
# --> 184     return func(*args, **kwargs)
#     186 func_sig = signature(func)
#     188 # Map *args/**kwargs to the function signature
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:1094, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     992 @validate_params(
#     993     {
#     994         "y_true": ["array-like"],
#    (...)
#    1003     y_true, y_score, *, pos_label=None, sample_weight=None, drop_intermediate=True
#    1004 ):
#    1005     """Compute Receiver operating characteristic (ROC).
#    1006
#    1007     Note: this implementation is restricted to the binary classification task.
#    (...)
#    1092     array([ inf, 0.8 , 0.4 , 0.35, 0.1 ])
#    1093     """
# -> 1094     fps, tps, thresholds = _binary_clf_curve(
#    1095         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#    1096     )
#    1098     # Attempt to drop thresholds corresponding to points in between and
#    1099     # collinear with other points. These are always suboptimal and do not
#    1100     # appear on a plotted ROC curve (and thus do not affect the AUC).
#    (...)
#    1105     # but does not drop more complicated cases like fps = [1, 3, 7],
#    1106     # tps = [1, 2, 4]; there is no harm in keeping too many thresholds.
#    1107     if drop_intermediate and len(fps) > 2:
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:838, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     834 # y_score typically has many tied values. Here we extract
#     835 # the indices associated with the distinct values. We also
#     836 # concatenate a value for the end of the curve.
#     837 distinct_value_indices = np.where(np.diff(y_score))[0]
# --> 838 threshold_idxs = np.r_[distinct_value_indices, y_true.size - 1]
#     840 # accumulate the true positives with decreasing threshold
#     841 tps = stable_cumsum(y_true * weight)[threshold_idxs]
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/index_tricks.py:417, in AxisConcatenator.__getitem__(self, key)
#     415 if final_dtype is not None:
#     416     for k in scalars:
# --> 417         objs[k] = objs[k].astype(final_dtype)
#     419 res = self.concatenate(tuple(objs), axis=axis)
#     421 if matrix:
#
# KeyboardInterrupt:

# %%
results_df = pd.read_pickle("task2_results.pkl")
results_df["Implementation_Rank"] = results_df["Implementation"].map(implementation_rank)
results_df.sort_values(by=["Data Percentage", "Implementation_Rank"], inplace=True, ascending=True)
results_df.drop("Implementation_Rank", axis=1, inplace=True)

# %%
gray_palette = sns.color_palette("gray", 6).as_hex()

# %% [markdown]
# ### Generate the figures
# The figures are reproduced using plotly

# %%
results_df_ = results_df[results_df["Data Percentage"] == 1]
for metric in ["mAP", "AUC"]:
    results_df_[f"e_plus_{metric}"] = results_df_[f"{metric}_high_CI"] - results_df_[metric]
    results_df_[f"e_minus_{metric}"] = results_df_[metric] - results_df_[f"{metric}_low_CI"]
    colors = ["#3182BD", "#00A3D5", *gray_palette]
    metric_values = results_df_[f"{metric}_values"].values

    fig = px.bar(
        results_df_,
        x="Implementation",
        y=metric,
        error_y=f"e_plus_{metric}",
        error_y_minus=f"e_minus_{metric}",
        color="Implementation",
        template="simple_white",
        labels={"Model": "", metric: metric, "Implementation": ""},
        color_discrete_sequence=colors,  # Use the blues color palette
        range_y=[0.4, 1],
    )

    random_val = np.random.rand(len(metric_values[0]))
    for sample_idx in range(len(metric_values[0])):
        fig.add_trace(
            go.Box(
                x=results_df_["Implementation"],
                y=[metric_values[i][sample_idx] for i in range(len(metric_values))],
                marker=dict(color="black", symbol="circle", size=1, line=dict(width=0)),
                fillcolor="rgba(255, 255, 255,0)",
                line=dict(
                    width=0,
                ),
                boxpoints="all",  # display the original data points
                opacity=0.2,
                pointpos=-1.6 + (random_val[sample_idx] * 3.2),
                showlegend=False,
            )
        )

    title = "Full training set"
    fig.update_layout(
        title=title,
        width=600,
        height=500,
        autosize=False,
        legend=dict(
            orientation="v",
        ),
        bargap=0,  # Reduce gap between bars
        template="simple_white",
        title_x=0.5,
        xaxis=dict(showticklabels=False),
        yaxis=dict(showgrid=True),
        xaxis_title=None,
        showlegend=True,
    ),
    fig.update_traces(marker_pattern_shape="\\", selector={"legendgroup": "Models Genesis (Finetuned)"})
    fig.update_traces(marker_pattern_shape="\\", selector={"legendgroup": "Models Genesis (Features)"})
    for trace in fig.data:
        if isinstance(trace, go.Bar):
            trace.error_y.thickness = 1
    fig.show()
    fig.write_image(f"figures_vector_pdf/task2_{metric}_dot.pdf")
    fig.data = []
# Out:
# /tmp/ipykernel_3082283/651567887.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_3082283/651567887.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="848bf6bc-cc26-4727-9c11-74f7cc122cb2" class="plotly-graph-div" style="height:500px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("848bf6bc-cc26-4727-9c11-74f7cc122cb2")) {                    Plotly.newPlot(                        "848bf6bc-cc26-4727-9c11-74f7cc122cb2",                        [{"alignmentgroup":"True","error_y":{"array":[0.040386253817417006],"arrayminus":[0.05016563677440922],"thickness":1},"hovertemplate":"=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Features)","marker":{"color":"#3182BD","pattern":{"shape":""}},"name":"Foundation (Features)","offsetgroup":"Foundation (Features)","orientation":"v","showlegend":true,"textposition":"auto","x":["Foundation (Features)"],"xaxis":"x","y":[0.9037544190123012],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.026125192235438188],"arrayminus":[0.034543576147709976],"thickness":1},"hovertemplate":"=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Finetuned)","marker":{"color":"#00A3D5","pattern":{"shape":""}},"name":"Foundation (Finetuned)","offsetgroup":"Foundation (Finetuned)","orientation":"v","showlegend":true,"textposition":"auto","x":["Foundation (Finetuned)"],"xaxis":"x","y":[0.951429944043339],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.06448935853411875],"arrayminus":[0.08189916508742356],"thickness":1},"hovertemplate":"=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supervised","marker":{"color":"#242424","pattern":{"shape":""}},"name":"Supervised","offsetgroup":"Supervised","orientation":"v","showlegend":true,"textposition":"auto","x":["Supervised"],"xaxis":"x","y":[0.8346710974296873],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.05098204375707893],"arrayminus":[0.0638043428992322],"thickness":1},"hovertemplate":"=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supervised (Finetuned)","marker":{"color":"#494949","pattern":{"shape":""}},"name":"Supervised (Finetuned)","offsetgroup":"Supervised (Finetuned)","orientation":"v","showlegend":true,"textposition":"auto","x":["Supervised (Finetuned)"],"xaxis":"x","y":[0.8744192979354893],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.09607269401870955],"arrayminus":[0.10464796924898023],"thickness":1},"hovertemplate":"=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Features)","marker":{"color":"#6d6d6d","pattern":{"shape":""}},"name":"Med3D (Features)","offsetgroup":"Med3D (Features)","orientation":"v","showlegend":true,"textposition":"auto","x":["Med3D (Features)"],"xaxis":"x","y":[0.7537035096821177],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.03438362433491582],"arrayminus":[0.043055559738758964],"thickness":1},"hovertemplate":"=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Finetuned)","marker":{"color":"#929292","pattern":{"shape":""}},"name":"Med3D (Finetuned)","offsetgroup":"Med3D (Finetuned)","orientation":"v","showlegend":true,"textposition":"auto","x":["Med3D (Finetuned)"],"xaxis":"x","y":[0.929849565030641],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.059993771593360945],"arrayminus":[0.07919422090744144],"thickness":1},"hovertemplate":"=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Models Genesis (Features)","marker":{"color":"#b6b6b6","pattern":{"shape":"\\"}},"name":"Models Genesis (Features)","offsetgroup":"Models Genesis (Features)","orientation":"v","showlegend":true,"textposition":"auto","x":["Models Genesis (Features)"] ...
# /tmp/ipykernel_3082283/651567887.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_3082283/651567887.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="69d8058e-fad5-46eb-8cdc-5d4ba9d631dc" class="plotly-graph-div" style="height:500px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69d8058e-fad5-46eb-8cdc-5d4ba9d631dc")) {                    Plotly.newPlot(                        "69d8058e-fad5-46eb-8cdc-5d4ba9d631dc",                        [{"alignmentgroup":"True","error_y":{"array":[0.04957311450415702],"arrayminus":[0.0577686780896447],"thickness":1},"hovertemplate":"=%{x}\u003cbr\u003eAUC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Features)","marker":{"color":"#3182BD","pattern":{"shape":""}},"name":"Foundation (Features)","offsetgroup":"Foundation (Features)","orientation":"v","showlegend":true,"textposition":"auto","x":["Foundation (Features)"],"xaxis":"x","y":[0.8830040928394323],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.028288207991200798],"arrayminus":[0.0363939210256905],"thickness":1},"hovertemplate":"=%{x}\u003cbr\u003eAUC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Finetuned)","marker":{"color":"#00A3D5","pattern":{"shape":""}},"name":"Foundation (Finetuned)","offsetgroup":"Foundation (Finetuned)","orientation":"v","showlegend":true,"textposition":"auto","x":["Foundation (Finetuned)"],"xaxis":"x","y":[0.9444426351049117],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.06316276584051905],"arrayminus":[0.06947380602864262],"thickness":1},"hovertemplate":"=%{x}\u003cbr\u003eAUC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supervised","marker":{"color":"#242424","pattern":{"shape":""}},"name":"Supervised","offsetgroup":"Supervised","orientation":"v","showlegend":true,"textposition":"auto","x":["Supervised"],"xaxis":"x","y":[0.816842190612608],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.051377936591399775],"arrayminus":[0.05993665280766036],"thickness":1},"hovertemplate":"=%{x}\u003cbr\u003eAUC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supervised (Finetuned)","marker":{"color":"#494949","pattern":{"shape":""}},"name":"Supervised (Finetuned)","offsetgroup":"Supervised (Finetuned)","orientation":"v","showlegend":true,"textposition":"auto","x":["Supervised (Finetuned)"],"xaxis":"x","y":[0.8585191079822436],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.06419953638502063],"arrayminus":[0.0708317418183394],"thickness":1},"hovertemplate":"=%{x}\u003cbr\u003eAUC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Features)","marker":{"color":"#6d6d6d","pattern":{"shape":""}},"name":"Med3D (Features)","offsetgroup":"Med3D (Features)","orientation":"v","showlegend":true,"textposition":"auto","x":["Med3D (Features)"],"xaxis":"x","y":[0.7682387873120666],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.04094543238108683],"arrayminus":[0.04658054185305027],"thickness":1},"hovertemplate":"=%{x}\u003cbr\u003eAUC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Finetuned)","marker":{"color":"#929292","pattern":{"shape":""}},"name":"Med3D (Finetuned)","offsetgroup":"Med3D (Finetuned)","orientation":"v","showlegend":true,"textposition":"auto","x":["Med3D (Finetuned)"],"xaxis":"x","y":[0.9157464611341851],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.05070350611409702],"arrayminus":[0.055675777734934484],"thickness":1},"hovertemplate":"=%{x}\u003cbr\u003eAUC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Models Genesis (Features)","marker":{"color":"#b6b6b6","pattern":{"shape":"\\"}},"name":"Models Genesis (Features)","offsetgroup":"Models Genesis (Features)","orientation":"v","showlegend":true,"textposition":"auto","x":["Models Genesis (Features)"],"x ...

# %%
for metric in ["mAP", "AUC"]:
    results_df[f"e_plus_{metric}"] = results_df[f"{metric}_high_CI"] - results_df[metric]
    results_df[f"e_minus_{metric}"] = results_df[metric] - results_df[f"{metric}_low_CI"]

    colors = ["#3182BD", "#00A3D5", *gray_palette]
    fig = px.line(
        results_df,
        x="Data Percentage",
        y=metric,
        # error_y=f"e_plus_{metric}",
        # error_y_minus=f"e_minus_{metric}",
        color="Implementation",
        markers=True,
        template="simple_white",
        labels={"Data Percentage": "Percentage", metric: metric},
        color_discrete_sequence=colors,  # Use the blues color palette
        range_y=[0.4, 1],
    )

    fig.update_traces(marker=dict(size=10))

    title = "Percentages of training data"
    fig.update_traces(
        error_y=dict(
            thickness=1,
        ),
    )
    fig.update_layout(
        title=title,
        width=600,
        height=600,
        autosize=True,
        showlegend=False,
        legend=dict(yanchor="bottom", y=-0.45, orientation="h", xanchor="right", x=1.2),
        template="simple_white",
        title_x=0.5,
        yaxis=dict(showgrid=True),
        xaxis=dict(
            tickmode="array",  # change 1
            tickvals=[0.1, 0.2, 0.5, 1],  # change 2
            ticktext=["10%", "20%", "50%", "100%"],  # change 3
            autorange="reversed",
        ),
    )
    fig.update_traces(patch={"line": {"dash": "dot"}}, selector={"legendgroup": "Models Genesis (Features)"})
    fig.update_traces(patch={"line": {"dash": "dot"}}, selector={"legendgroup": "Models Genesis (Finetuned)"})

    fig.show()
    fig.write_image(f"figures_vector_pdf/task2_{metric}_percentages.pdf")
    fig.data = []
# Out:
# <div>                            <div id="5bad660f-9765-46ba-b343-ee1191c5ae89" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bad660f-9765-46ba-b343-ee1191c5ae89")) {                    Plotly.newPlot(                        "5bad660f-9765-46ba-b343-ee1191c5ae89",                        [{"hovertemplate":"Implementation=Foundation (Features)\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Features)","line":{"color":"#3182BD","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Foundation (Features)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.8468808299911548,0.8955175770823567,0.9023884244516731,0.9037544190123012],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Foundation (Finetuned)\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Finetuned)","line":{"color":"#00A3D5","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Foundation (Finetuned)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.5257805830166108,0.822995495149112,0.9088645803355186,0.951429944043339],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Supervised\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supervised","line":{"color":"#242424","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Supervised","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.530478942721284,0.5880223553079695,0.7537286111452197,0.8346710974296873],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Supervised (Finetuned)\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supervised (Finetuned)","line":{"color":"#494949","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Supervised (Finetuned)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.587809157539686,0.6471416655390294,0.812937281388566,0.8744192979354893],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Med3D (Features)\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Features)","line":{"color":"#6d6d6d","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Med3D (Features)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.7045417740729221,0.7079313412082746,0.7298898880768111,0.7537035096821177],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Med3D (Finetuned)\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Finetuned)","line":{"color":"#929292","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Med3D (Finetuned)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.6034940249332708,0.5555907635892999,0.8096693520719814,0.929849565030641],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Models Genesis (Features)\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Models Genesis (Features)","line":{"color":"#b6b6b6","dash":"dot"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Models Genesis (Features)","orientation":"v","showlegend" ...
# <div>                            <div id="ed8c3752-c874-4306-90bf-77d5725bde6e" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed8c3752-c874-4306-90bf-77d5725bde6e")) {                    Plotly.newPlot(                        "ed8c3752-c874-4306-90bf-77d5725bde6e",                        [{"hovertemplate":"Implementation=Foundation (Features)\u003cbr\u003ePercentage=%{x}\u003cbr\u003eAUC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Features)","line":{"color":"#3182BD","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Foundation (Features)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.8270084963262961,0.8763011452551511,0.8835937735351436,0.8830040928394323],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Foundation (Finetuned)\u003cbr\u003ePercentage=%{x}\u003cbr\u003eAUC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation (Finetuned)","line":{"color":"#00A3D5","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Foundation (Finetuned)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.5243480047135612,0.7933086455635617,0.8874552923977481,0.9444426351049117],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Supervised\u003cbr\u003ePercentage=%{x}\u003cbr\u003eAUC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supervised","line":{"color":"#242424","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Supervised","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.5161920945972984,0.5893583799059293,0.7510450020455632,0.816842190612608],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Supervised (Finetuned)\u003cbr\u003ePercentage=%{x}\u003cbr\u003eAUC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supervised (Finetuned)","line":{"color":"#494949","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Supervised (Finetuned)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.6157731546255779,0.6211952928427691,0.7869382836814496,0.8585191079822436],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Med3D (Features)\u003cbr\u003ePercentage=%{x}\u003cbr\u003eAUC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Features)","line":{"color":"#6d6d6d","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Med3D (Features)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.7028458573353642,0.7558668667931658,0.7705402735433138,0.7682387873120666],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Med3D (Finetuned)\u003cbr\u003ePercentage=%{x}\u003cbr\u003eAUC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Med3D (Finetuned)","line":{"color":"#929292","dash":"solid"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Med3D (Finetuned)","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.6065790052104353,0.5475759120172435,0.8043490857674096,0.9157464611341851],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"Implementation=Models Genesis (Features)\u003cbr\u003ePercentage=%{x}\u003cbr\u003eAUC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Models Genesis (Features)","line":{"color":"#b6b6b6","dash":"dot"},"marker":{"symbol":"circle","size":10},"mode":"lines+markers","name":"Models Genesis (Features)","orientation":"v","showle ...
