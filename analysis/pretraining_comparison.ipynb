# %% [markdown]
# ## Reproduce Analysis for Task 1 corresponding to Figure 2 in the paper.
#
# This notebook contains code and analysis for reproducing results for Figure 2

# %%
from scipy.stats import bootstrap, permutation_test
import pandas as pd
from pathlib import Path
import scipy
from functools import partial
import numpy as np
import plotly
from tqdm import tqdm
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import seaborn as sns

pio.templates["custom"] = go.layout.Template(
    layout=go.Layout(
        colorway=px.colors.qualitative.D3,
    )
)

from utils import get_model_stats, get_model_comparison_stats

# %% [markdown]
# ### Load CSV files for each of the implementation approach predictions
#
# We load saved prediction files for each of the implementation approaches. The CSV contains the predicted probabilities for each of the 8 anatomical sites and the true label from the dataset. It also contains information about several other parameters such as lesion type, etc.

# %%
path = Path("../outputs/predictions/task1")

# %%
implementation_dict = {
    "Auto-Encoder": [csv_path for csv_path in path.glob("autoencoder_features*.csv")],
    "SimCLR": [csv_path for csv_path in path.glob("simclr_features*.csv")],
    "SwAV": [csv_path for csv_path in path.glob("swav_features*.csv")],
    "NNCLR": [csv_path for csv_path in path.glob("nnclr_features*.csv")],
    "Our modified SimCLR": [csv_path for csv_path in path.glob("foundation_features*.csv")],
}

implementation_rank = {key: i for i, key in enumerate(implementation_dict.keys())}

# %%
implementation_rank = {key: i for i, key in enumerate(implementation_dict.keys())}
pbar = tqdm(total=len(implementation_dict) * len(implementation_dict["SimCLR"]))
results = []

# We use 1000 resamples in the study, but for the sake of time we use reproduce results with 10 here
N_RESAMPLES = 1000
for implementation_name, implementation_list in implementation_dict.items():
    for model_prediction_csv in implementation_list:
        data_percentage = (
            float(model_prediction_csv.stem.split("_")[-2]) / 100 if len(model_prediction_csv.stem.split("_")) > 2 else 1.0
        )
        df = pd.read_csv(model_prediction_csv)

        for i in range(8):
            if f"conf_scores_class_{i}" not in df.columns:
                df[f"conf_scores_class_{i}"] = 0

        pred_set = (df["Coarse_lesion_type"].values, df.filter(like="conf_scores").values)
        map_values = get_model_stats(
            *pred_set,
            fn="mean_average_precision",
            nsamples=N_RESAMPLES,
        )

        ba_values = get_model_stats(
            *pred_set,
            fn="balanced_accuracy",
            nsamples=N_RESAMPLES,
        )

        row = {
            "Implementation": implementation_name,
            "Data Percentage": data_percentage,
            "mAP": np.mean(map_values),
            "mAP_values": map_values,
            "mAP_low_CI": np.percentile(map_values, 2.5),
            "mAP_high_CI": np.percentile(map_values, 97.5),
            "BA": np.mean(ba_values),
            "BA_low_CI": np.percentile(ba_values, 2.5),
            "BA_high_CI": np.percentile(ba_values, 97.5),
            "BA_values": ba_values,
        }

        # Compute statistics for comparison between this implementation and all other ones (difference CI and p-value)
        compare_impementations = {k: v for k, v in implementation_dict.items() if k != implementation_name}
        for _implementation_name, _implementations_list in compare_impementations.items():
            for _model_prediction_csv in _implementations_list:
                _data_percentage = (
                    float(_model_prediction_csv.stem.split("_")[-2]) / 100
                    if len(_model_prediction_csv.stem.split("_")) > 2
                    else 1.0
                )
                if data_percentage == _data_percentage:
                    _df = pd.read_csv(_model_prediction_csv)
                    # Check if 8 columns with conf_scores_class_{idx} exist, if not add a column with zeros for missing
                    for i in range(8):
                        if f"conf_scores_class_{i}" not in _df.columns:
                            _df[f"conf_scores_class_{i}"] = 0

                    _pred = _df.filter(like="conf_scores").values
                    _pred_set = (*pred_set, _pred)

                    perm_test = get_model_comparison_stats(
                        *_pred_set,
                        fn="balanced_accuracy",
                        nsamples=N_RESAMPLES,
                    )

                    row[f"BA_diff_CI_low_{_implementation_name}"] = perm_test[0][0]
                    row[f"BA_diff_CI_high_{_implementation_name}"] = perm_test[0][1]
                    row[f"BA_pval_{_implementation_name}"] = perm_test[1]

                    perm_test = get_model_comparison_stats(
                        *_pred_set,
                        fn="mean_average_precision",
                        nsamples=N_RESAMPLES,
                    )

                    row[f"mAP_diff_CI_low_{_implementation_name}"] = perm_test[0][0]
                    row[f"mAP_diff_CI_high_{_implementation_name}"] = perm_test[0][1]
                    row[f"mAP_pval_{_implementation_name}"] = perm_test[1]

        results.append(row)
        pbar.update(1)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/pretraining_comparison.ipynb Cell 6 line 7
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/pretraining_comparison.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=70'>71</a> row[f"BA_diff_CI_high_{_implementation_name}"] = perm_test[0][1]
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/pretraining_comparison.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=71'>72</a> row[f"BA_pval_{_implementation_name}"] = perm_test[1]
# ---> <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/pretraining_comparison.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=73'>74</a> perm_test = get_model_comparison_stats(
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/pretraining_comparison.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=74'>75</a>     *_pred_set,
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/pretraining_comparison.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=75'>76</a>     fn="mean_average_precision",
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/pretraining_comparison.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=76'>77</a>     nsamples=N_RESAMPLES,
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/pretraining_comparison.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=77'>78</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/pretraining_comparison.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=79'>80</a> row[f"mAP_diff_CI_low_{_implementation_name}"] = perm_test[0][0]
#      <a href='vscode-notebook-cell://ssh-remote%2Br2z9/home/suraj/Repositories/foundation-cancer-image-biomarker/analysis/pretraining_comparison.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=80'>81</a> row[f"mAP_diff_CI_high_{_implementation_name}"] = perm_test[0][1]
#
# File ~/Repositories/foundation-cancer-image-biomarker/analysis/utils.py:48, in get_model_comparison_stats(y_true, pred_proba_1, pred_proba_2, nsamples, fn)
#      45     y_pred_sample_2 = pred_proba_2[idx]
#      47     metric1 = eval(fn)(y_true_sample, y_pred_sample_1)
# ---> 48     metric2 = eval(fn)(y_true_sample, y_pred_sample_2)
#      49     bootstrap_auc_differences.append(metric1 - metric2)
#      51 pvalue = np.mean(np.array(auc_differences) >= observed_difference)
#
# File ~/Repositories/foundation-cancer-image-biomarker/analysis/utils.py:17, in mean_average_precision(y_true, y_pred)
#      15 def mean_average_precision(y_true, y_pred):
#      16     y_true = label_binarize(y_true, classes=np.unique(y_true))
# ---> 17     avg_precisions = [average_precision_score(y_true[:, i], y_pred[:, i]) for i in range(y_true.shape[1])]
#      18     return np.mean(avg_precisions)
#
# File ~/Repositories/foundation-cancer-image-biomarker/analysis/utils.py:17, in <listcomp>(.0)
#      15 def mean_average_precision(y_true, y_pred):
#      16     y_true = label_binarize(y_true, classes=np.unique(y_true))
# ---> 17     avg_precisions = [average_precision_score(y_true[:, i], y_pred[:, i]) for i in range(y_true.shape[1])]
#      18     return np.mean(avg_precisions)
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:267, in average_precision_score(y_true, y_score, average, pos_label, sample_weight)
#     262     y_true = label_binarize(y_true, classes=present_labels)
#     264 average_precision = partial(
#     265     _binary_uninterpolated_average_precision, pos_label=pos_label
#     266 )
# --> 267 return _average_binary_score(
#     268     average_precision, y_true, y_score, average, sample_weight=sample_weight
#     269 )
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/metrics/_base.py:75, in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      72     raise ValueError("{0} format is not supported".format(y_type))
#      74 if y_type == "binary":
# ---> 75     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      77 check_consistent_length(y_true, y_score, sample_weight)
#      78 y_true = check_array(y_true)
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:229, in average_precision_score.<locals>._binary_uninterpolated_average_precision(y_true, y_score, pos_label, sample_weight)
#     226 def _binary_uninterpolated_average_precision(
#     227     y_true, y_score, pos_label=1, sample_weight=None
#     228 ):
# --> 229     precision, recall, _ = precision_recall_curve(
#     230         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#     231     )
#     232     # Return the step function integral
#     233     # The following works because the last entry of precision is
#     234     # guaranteed to be 1, as returned by precision_recall_curve
#     235     return -np.sum(np.diff(recall) * np.array(precision)[:-1])
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:184, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     182 global_skip_validation = get_config()["skip_parameter_validation"]
#     183 if global_skip_validation:
# --> 184     return func(*args, **kwargs)
#     186 func_sig = signature(func)
#     188 # Map *args/**kwargs to the function signature
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:951, in precision_recall_curve(y_true, probas_pred, pos_label, sample_weight, drop_intermediate)
#     851 @validate_params(
#     852     {
#     853         "y_true": ["array-like"],
#    (...)
#     862     y_true, probas_pred, *, pos_label=None, sample_weight=None, drop_intermediate=False
#     863 ):
#     864     """Compute precision-recall pairs for different probability thresholds.
#     865
#     866     Note: this implementation is restricted to the binary classification task.
#    (...)
#     949     array([0.1 , 0.35, 0.4 , 0.8 ])
#     950     """
# --> 951     fps, tps, thresholds = _binary_clf_curve(
#     952         y_true, probas_pred, pos_label=pos_label, sample_weight=sample_weight
#     953     )
#     955     if drop_intermediate and len(fps) > 2:
#     956         # Drop thresholds corresponding to points where true positives (tps)
#     957         # do not change from the previous or subsequent point. This will keep
#     958         # only the first and last point for each tps value. All points
#     959         # with the same tps value have the same recall and thus x coordinate.
#     960         # They appear as a vertical line on the plot.
#     961         optimal_idxs = np.where(
#     962             np.concatenate(
#     963                 [[True], np.logical_or(np.diff(tps[:-1]), np.diff(tps[1:])), [True]]
#     964             )
#     965         )[0]
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:820, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     817     y_score = y_score[nonzero_weight_mask]
#     818     sample_weight = sample_weight[nonzero_weight_mask]
# --> 820 pos_label = _check_pos_label_consistency(pos_label, y_true)
#     822 # make y_true a boolean vector
#     823 y_true = y_true == pos_label
#
# File ~/miniconda3/envs/fmcib_env/lib/python3.8/site-packages/sklearn/utils/validation.py:2234, in _check_pos_label_consistency(pos_label, y_true)
#    2206 """Check if `pos_label` need to be specified or not.
#    2207
#    2208 In binary classification, we fix `pos_label=1` if the labels are in the set
#    (...)
#    2228     it will raise a `ValueError`.
#    2229 """
#    2230 # ensure binary classification if pos_label is not specified
#    2231 # classes.dtype.kind in ('O', 'U', 'S') is required to avoid
#    2232 # triggering a FutureWarning by calling np.array_equal(a, b)
#    2233 # when elements in the two arrays are not comparable.
# -> 2234 classes = np.unique(y_true)
#    2235 if pos_label is None and (
#    2236     classes.dtype.kind in "OUS"
#    2237     or not (
#    (...)
#    2243     )
#    2244 ):
#    2245     classes_repr = ", ".join(repr(c) for c in classes)
#
# File <__array_function__ internals>:200, in unique(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py:336, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     334     aux = ar[perm]
#     335 else:
# --> 336     ar.sort()
#     337     aux = ar
#     338 mask = np.empty(aux.shape, dtype=np.bool_)
#
# KeyboardInterrupt:

# %%
results_df = pd.DataFrame(results)

# %% [markdown]
# ### Analysis for computing metrics for each of the implementation approaches
#
# Here we compute the metrics for each of the implementation approaches along with the 95% confidence intervals. Each implementation approach is also compared to all other implementation
# approaches with a difference confidence interval and p-value. We bootstrap to compute the confidence intervals and run a permutation test for the p-values.

# %%
results_df = pd.read_pickle("pretraining_results.pkl")
results_df["Implementation_Rank"] = results_df["Implementation"].map(implementation_rank)
results_df.sort_values(by=["Data Percentage", "Implementation_Rank"], inplace=True, ascending=True)
results_df.drop("Implementation_Rank", axis=1, inplace=True)

# %% [markdown]
# ### Generate the figures
# The figures are reproduced using plotly

# %%
results_df_ = results_df[results_df["Data Percentage"] == 1]
n_colors = len(results_df_["Implementation"].unique()) + 2
colors = px.colors.sample_colorscale("Greens", [n / (n_colors - 1) for n in range(n_colors)])[2:]

for metric in ["mAP", "BA"]:
    results_df_[f"e_plus_{metric}"] = results_df_[f"{metric}_high_CI"] - results_df_[metric]
    results_df_[f"e_minus_{metric}"] = results_df_[metric] - results_df_[f"{metric}_low_CI"]
    metric_values = results_df_[f"{metric}_values"].values

    fig = px.bar(
        results_df_,
        x="Implementation",
        y=metric,
        error_y=f"e_plus_{metric}",
        error_y_minus=f"e_minus_{metric}",
        color="Implementation",
        template="simple_white",
        labels={"Model": "", metric: metric, "Implementation": "SSL methods"},
        color_discrete_sequence=colors,
        range_y=[0.4, 1],
    )

    random_val = np.random.rand(len(metric_values[0]))
    for sample_idx in range(len(metric_values[0])):
        fig.add_trace(
            go.Box(
                x=results_df_["Implementation"],
                y=[metric_values[i][sample_idx] for i in range(len(metric_values))],
                marker=dict(color="black", symbol="circle", size=1, line=dict(width=0)),
                fillcolor="rgba(255, 255, 255,0)",
                line=dict(
                    width=0,
                ),
                boxpoints="all",  # display the original data points
                opacity=0.4,
                pointpos=-1.6 + (random_val[sample_idx] * 3.2),
                showlegend=False,
            )
        )

    title = "Full training set"
    fig.update_layout(
        title=title,
        width=600,
        height=500,
        autosize=True,
        legend=dict(orientation="v"),
        bargap=0,  # Reduce gap between bars
        template="simple_white",
        title_x=0.5,
        xaxis=dict(showticklabels=False),
        yaxis=dict(showgrid=True),
        xaxis_title=None,
        showlegend=True,
    ),

    for trace in fig.data:
        if isinstance(trace, go.Bar):
            trace.error_y.thickness = 1

    fig.show()
    fig.write_image(f"figures_vector_pdf/pretraining_{metric}_dot.pdf")

    fig.data = []
# Out:
# /tmp/ipykernel_3083394/2921161363.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_3083394/2921161363.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="0531ce21-c910-4d58-ac77-47065daf23ac" class="plotly-graph-div" style="height:500px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0531ce21-c910-4d58-ac77-47065daf23ac")) {                    Plotly.newPlot(                        "0531ce21-c910-4d58-ac77-47065daf23ac",                        [{"alignmentgroup":"True","error_y":{"array":[0.037569974112471316],"arrayminus":[0.03735671011703545],"thickness":1},"hovertemplate":"SSL methods=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Auto-Encoder","marker":{"color":"rgb(174, 222, 167)","pattern":{"shape":""}},"name":"Auto-Encoder","offsetgroup":"Auto-Encoder","orientation":"v","showlegend":true,"textposition":"auto","x":["Auto-Encoder"],"xaxis":"x","y":[0.6551905404759997],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.030062810524478567],"arrayminus":[0.03206324107994829],"thickness":1},"hovertemplate":"SSL methods=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SimCLR","marker":{"color":"rgb(116, 196, 118)","pattern":{"shape":""}},"name":"SimCLR","offsetgroup":"SimCLR","orientation":"v","showlegend":true,"textposition":"auto","x":["SimCLR"],"xaxis":"x","y":[0.777650843193253],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.03700683349369038],"arrayminus":[0.038457968887019134],"thickness":1},"hovertemplate":"SSL methods=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SwAV","marker":{"color":"rgb(55, 160, 85)","pattern":{"shape":""}},"name":"SwAV","offsetgroup":"SwAV","orientation":"v","showlegend":true,"textposition":"auto","x":["SwAV"],"xaxis":"x","y":[0.7074730183602665],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.032249666838110924],"arrayminus":[0.035555207747174467],"thickness":1},"hovertemplate":"SSL methods=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NNCLR","marker":{"color":"rgb(12, 119, 52)","pattern":{"shape":""}},"name":"NNCLR","offsetgroup":"NNCLR","orientation":"v","showlegend":true,"textposition":"auto","x":["NNCLR"],"xaxis":"x","y":[0.7087841152740031],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.02948055611408129],"arrayminus":[0.031697716725514025],"thickness":1},"hovertemplate":"SSL methods=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Our modified SimCLR","marker":{"color":"rgb(0, 68, 27)","pattern":{"shape":""}},"name":"Our modified SimCLR","offsetgroup":"Our modified SimCLR","orientation":"v","showlegend":true,"textposition":"auto","x":["Our modified SimCLR"],"xaxis":"x","y":[0.8472541435790485],"yaxis":"y","type":"bar"},{"boxpoints":"all","fillcolor":"rgba(255, 255, 255,0)","line":{"width":0},"marker":{"color":"black","line":{"width":0},"size":1,"symbol":"circle"},"opacity":0.4,"pointpos":-0.7306689461928784,"showlegend":false,"x":["Auto-Encoder","SimCLR","SwAV","NNCLR","Our modified SimCLR"],"y":[0.6384383009895491,0.7764200877974894,0.7350062869579231,0.6985595015334202,0.8233782751521804],"type":"box"},{"boxpoints":"all","fillcolor":"rgba(255, 255, 255,0)","line":{"width":0},"marker":{"color":"black","line":{"width":0},"size":1,"symbol":"circle"},"opacity":0.4,"pointpos":0.22371676066797574,"showlegend":false,"x":["Auto-Encoder","SimCLR","SwAV","NNCLR","Our modified SimCLR"],"y":[0.6560815920526772,0.7923773086017001,0.7085944585074768,0.7010118219104855,0.8572991545987174],"type":"box"},{"boxpoints":"all","fillcolor":"rgba(255, 255, 255,0)","line":{"width":0},"marker":{"color":"black","line":{"width":0},"size":1,"symbol":"circle"},"opacity":0.4,"pointpos":-0.35479405341073766,"showlegend":false,"x":["Auto-Encoder","SimCLR","SwAV","NN ...
# /tmp/ipykernel_3083394/2921161363.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_3083394/2921161363.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="b146653e-eab7-4e55-a492-5c21a8946612" class="plotly-graph-div" style="height:500px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b146653e-eab7-4e55-a492-5c21a8946612")) {                    Plotly.newPlot(                        "b146653e-eab7-4e55-a492-5c21a8946612",                        [{"alignmentgroup":"True","error_y":{"array":[0.036811972428717143],"arrayminus":[0.03649176233995399],"thickness":1},"hovertemplate":"SSL methods=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Auto-Encoder","marker":{"color":"rgb(174, 222, 167)","pattern":{"shape":""}},"name":"Auto-Encoder","offsetgroup":"Auto-Encoder","orientation":"v","showlegend":true,"textposition":"auto","x":["Auto-Encoder"],"xaxis":"x","y":[0.6126550809572381],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.03299269678147121],"arrayminus":[0.03333803285574388],"thickness":1},"hovertemplate":"SSL methods=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SimCLR","marker":{"color":"rgb(116, 196, 118)","pattern":{"shape":""}},"name":"SimCLR","offsetgroup":"SimCLR","orientation":"v","showlegend":true,"textposition":"auto","x":["SimCLR"],"xaxis":"x","y":[0.6974116233028035],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.033415155180745226],"arrayminus":[0.03490319486359139],"thickness":1},"hovertemplate":"SSL methods=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SwAV","marker":{"color":"rgb(55, 160, 85)","pattern":{"shape":""}},"name":"SwAV","offsetgroup":"SwAV","orientation":"v","showlegend":true,"textposition":"auto","x":["SwAV"],"xaxis":"x","y":[0.6376155166227998],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.032269482339364],"arrayminus":[0.035404665897048604],"thickness":1},"hovertemplate":"SSL methods=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NNCLR","marker":{"color":"rgb(12, 119, 52)","pattern":{"shape":""}},"name":"NNCLR","offsetgroup":"NNCLR","orientation":"v","showlegend":true,"textposition":"auto","x":["NNCLR"],"xaxis":"x","y":[0.6678489295519924],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.029144516182399327],"arrayminus":[0.030863702684055805],"thickness":1},"hovertemplate":"SSL methods=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Our modified SimCLR","marker":{"color":"rgb(0, 68, 27)","pattern":{"shape":""}},"name":"Our modified SimCLR","offsetgroup":"Our modified SimCLR","orientation":"v","showlegend":true,"textposition":"auto","x":["Our modified SimCLR"],"xaxis":"x","y":[0.7794395166763134],"yaxis":"y","type":"bar"},{"boxpoints":"all","fillcolor":"rgba(255, 255, 255,0)","line":{"width":0},"marker":{"color":"black","line":{"width":0},"size":1,"symbol":"circle"},"opacity":0.4,"pointpos":0.7404430686435668,"showlegend":false,"x":["Auto-Encoder","SimCLR","SwAV","NNCLR","Our modified SimCLR"],"y":[0.6361599030906745,0.7109261867060723,0.6309375808090769,0.6591622188473983,0.7827798839236716],"type":"box"},{"boxpoints":"all","fillcolor":"rgba(255, 255, 255,0)","line":{"width":0},"marker":{"color":"black","line":{"width":0},"size":1,"symbol":"circle"},"opacity":0.4,"pointpos":1.22905674842844,"showlegend":false,"x":["Auto-Encoder","SimCLR","SwAV","NNCLR","Our modified SimCLR"],"y":[0.5874448369580738,0.6664580920148515,0.6602478430515673,0.6682505574997883,0.7725253727219981],"type":"box"},{"boxpoints":"all","fillcolor":"rgba(255, 255, 255,0)","line":{"width":0},"marker":{"color":"black","line":{"width":0},"size":1,"symbol":"circle"},"opacity":0.4,"pointpos":-1.1428162728853792,"showlegend":false,"x":["Auto-Encoder","SimCLR","SwAV","NNCLR","Our mo ...

# %%
results_df["Data Percentage"] = results_df["Data Percentage"].apply(lambda x: f"{int(x * 100)}%")

# %%
for metric in ["mAP", "BA"]:
    results_df[f"e_plus_{metric}"] = results_df[f"{metric}_high_CI"] - results_df[metric]
    results_df[f"e_minus_{metric}"] = results_df[metric] - results_df[f"{metric}_low_CI"]

    fig = px.line(
        results_df,
        x="Data Percentage",
        y=metric,
        # error_y=f"e_plus_{metric}",
        # error_y_minus=f"e_minus_{metric}",
        color="Implementation",
        markers=True,
        template="simple_white",
        labels={"Data Percentage": "Percentage", metric: metric, "Implementation": "SSL methods"},
        color_discrete_sequence=colors,  # Use the blues color palette
        range_y=[0.4, 1],
    )

    fig.update_traces(marker=dict(size=10))
    fig.update_traces(marker=dict(symbol="star"))

    title = "Percentages of training data"
    fig.update_traces(
        error_y=dict(
            thickness=1,
        ),
    )
    fig.update_layout(
        title=title,
        width=600,
        height=600,
        autosize=True,
        showlegend=True,
        legend=dict(yanchor="bottom", y=-0.4, orientation="h", xanchor="right", x=1),
        template="simple_white",
        title_x=0.5,
        yaxis=dict(showgrid=True),
        xaxis=dict(
            tickmode="array",  # change 1
            tickvals=[0.1, 0.2, 0.5, 1],  # change 2
            ticktext=["10%", "20%", "50%", "100%"],  # change 3
            autorange="reversed",
        ),
    )

    fig.show()
    fig.write_image(f"figures_vector_pdf/pretraining_percentage_{metric}.pdf")

    fig.data = []
# Out:
# <div>                            <div id="ac0d15a6-eec0-4616-b6dc-d671f88e2b49" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac0d15a6-eec0-4616-b6dc-d671f88e2b49")) {                    Plotly.newPlot(                        "ac0d15a6-eec0-4616-b6dc-d671f88e2b49",                        [{"hovertemplate":"SSL methods=Auto-Encoder\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Auto-Encoder","line":{"color":"rgb(174, 222, 167)","dash":"solid"},"marker":{"symbol":"star","size":10},"mode":"markers+lines","name":"Auto-Encoder","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.5007918689211812,0.5374387221467678,0.5978424450209902,0.6551905404759997],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"SSL methods=SimCLR\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SimCLR","line":{"color":"rgb(116, 196, 118)","dash":"solid"},"marker":{"symbol":"star","size":10},"mode":"markers+lines","name":"SimCLR","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.6364950223911838,0.6490199723130329,0.7341059463800779,0.777650843193253],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"SSL methods=SwAV\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SwAV","line":{"color":"rgb(55, 160, 85)","dash":"solid"},"marker":{"symbol":"star","size":10},"mode":"markers+lines","name":"SwAV","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.5916032480008399,0.6258094624543169,0.6700873837284949,0.7074730183602665],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"SSL methods=NNCLR\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NNCLR","line":{"color":"rgb(12, 119, 52)","dash":"solid"},"marker":{"symbol":"star","size":10},"mode":"markers+lines","name":"NNCLR","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.542668172009076,0.6090173037834664,0.6668730108114816,0.7087841152740031],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"SSL methods=Our modified SimCLR\u003cbr\u003ePercentage=%{x}\u003cbr\u003emAP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Our modified SimCLR","line":{"color":"rgb(0, 68, 27)","dash":"solid"},"marker":{"symbol":"star","size":10},"mode":"markers+lines","name":"Our modified SimCLR","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.743177137371781,0.7811571659112851,0.8192968290005056,0.8472541435790485],"yaxis":"y","type":"scatter","error_y":{"thickness":1}}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36, ...
# <div>                            <div id="349c0d7e-961b-4b40-8220-4513a72513e5" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("349c0d7e-961b-4b40-8220-4513a72513e5")) {                    Plotly.newPlot(                        "349c0d7e-961b-4b40-8220-4513a72513e5",                        [{"hovertemplate":"SSL methods=Auto-Encoder\u003cbr\u003ePercentage=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Auto-Encoder","line":{"color":"rgb(174, 222, 167)","dash":"solid"},"marker":{"symbol":"star","size":10},"mode":"markers+lines","name":"Auto-Encoder","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.46836041477988527,0.4829049581356539,0.5770831678973171,0.6126550809572381],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"SSL methods=SimCLR\u003cbr\u003ePercentage=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SimCLR","line":{"color":"rgb(116, 196, 118)","dash":"solid"},"marker":{"symbol":"star","size":10},"mode":"markers+lines","name":"SimCLR","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.6031621998716046,0.6173757981662875,0.6808054475317477,0.6974116233028035],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"SSL methods=SwAV\u003cbr\u003ePercentage=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SwAV","line":{"color":"rgb(55, 160, 85)","dash":"solid"},"marker":{"symbol":"star","size":10},"mode":"markers+lines","name":"SwAV","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.5684515784241357,0.5715388335656072,0.619403756997737,0.6376155166227998],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"SSL methods=NNCLR\u003cbr\u003ePercentage=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NNCLR","line":{"color":"rgb(12, 119, 52)","dash":"solid"},"marker":{"symbol":"star","size":10},"mode":"markers+lines","name":"NNCLR","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.45256927526774243,0.5478413586060862,0.6265892059963248,0.6678489295519924],"yaxis":"y","type":"scatter","error_y":{"thickness":1}},{"hovertemplate":"SSL methods=Our modified SimCLR\u003cbr\u003ePercentage=%{x}\u003cbr\u003eBA=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Our modified SimCLR","line":{"color":"rgb(0, 68, 27)","dash":"solid"},"marker":{"symbol":"star","size":10},"mode":"markers+lines","name":"Our modified SimCLR","orientation":"v","showlegend":true,"x":[0.1,0.2,0.5,1.0],"xaxis":"x","y":[0.7077536171507949,0.7094363858810879,0.7443087377899044,0.7794395166763134],"yaxis":"y","type":"scatter","error_y":{"thickness":1}}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,3 ...
